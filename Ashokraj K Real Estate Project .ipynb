# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
Est=pd.read_csv("C:/Users/hp/Downloads/Real Estate.csv")

# %% [markdown]
# ## Basic and Info

# %%
Est.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
Est['total_bedrooms'].fillna(value=np.mean(Est['total_bedrooms']),inplace=True)

# %%
Est['total_bedrooms'].isnull().sum()
# Out:
# 0

# %%
Est.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
Est.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300

# %%
Est.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300

# %%
Est['total_bedrooms']=Est['total_bedrooms'].astype(int)

# %%
Est.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.24     37.85                  52         1467             190
# 3    -122.25     37.85                  52         1274             235
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300

# %%
Est.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  int32
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(3), int32(1), int64(5), object(1)
# memory usage: 1.5+ MB

# %%
Est.describe().round(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count   20640.00  20640.00            20640.00     20640.00        20640.00
# mean     -119.57     35.63               28.64      2635.76          537.86
# std         2.00      2.14               12.59      2181.62          419.27
# min      -124.35     32.54                1.00         2.00            1.00
# 25%      -121.80     33.93               18.00      1447.75          297.00
# 50%      -118.49     34.26               29.00      2127.00          438.00
# 75%      -118.01     37.71               37.00      3148.00          643.25
# max      -114.31     41.95               52.00     39320.00         6445.00
#
#        population  households  median_income  median_house_value
# count    20640.00    20640.00       20640.00            20640.00
# mean      1425.48      499.54           3.87           206855.82
# std       1132.46      382.33           1.90           115395.62
# ...

# %%
Est.shape
# Out:
# (20640, 10)

# %%
np.mean(Est.total_rooms)
# Out:
# 2635.7630813953488

# %%
np.mean(Est.total_bedrooms)
# Out:
# 537.8618217054263

# %% [markdown]
# ## Visualizing

# %%
sns.lmplot(x='households',y='median_house_value',height=5,aspect=3,data=Est)

# %%
sns.set_context('notebook',font_scale=2)
sns.countplot(x="population",data=Est,palette="coolwarm")

# %%
Est.shape
# Out:
# (20640, 10)

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='ocean_proximity',data=Est)

# %%
sns.heatmap(Est.corr())

# %%
sns.distplot(Est['housing_median_age'])

# %%
sns.jointplot(x='median_income',y='housing_median_age',data=Est,kind='hex')

# %%
sns.pairplot(Est)

# %% [markdown]
# ## Predictind Accuracy

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
Est.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.24     37.85                  52         1467             190
# 3    -122.25     37.85                  52         1274             235
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300

# %%
Est['ocean_proximity']=LE.fit_transform(Est["ocean_proximity"])

# %%
Est.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.24     37.85                  52         1467             190
# 3    -122.25     37.85                  52         1274             235
#
#    population  households  median_income  ocean_proximity  median_house_value
# 0         322         126         8.3252                3              452600
# 1        2401        1138         8.3014                3              358500
# 2         496         177         7.2574                3              352100
# 3         558         219         5.6431                3              341300

# %%
x=Est.iloc[:,[0,1,2,3,4,6,8,9]]

# %%
y=Est.iloc[:,5]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_test.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13015    -121.19     38.71                  11         4415             537
# 13660    -117.32     34.02                  17         1779             292
# 3367     -120.37     40.17                  21          789             141
# 6503     -118.05     34.08                  30         1572             427
# 3823     -118.47     34.20                  25         4590            1477
#
#        households  ocean_proximity  median_house_value
# 13015         627                1              390800
# 13660         293                1              123100
# 3367          146                1               73500
# 6503          428                0              159200
# 3823         1195                0              281700

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_test
# Out:
# 13015    1520
# 13660    1006
# 3367      406
# 6503     1857
# 3823     2723
#          ...
# 4440     3062
# 5080     1208
# 19522     198
# 11401    2095
# 2996     1267
# Name: population, Length: 4128, dtype: int64

# %%
pred=lm.predict(x_test)
pred
# Out:
# array([1642.95568648, 1038.75095808,  258.66203436, ...,  472.29856774,
#        1869.85086421, 1350.42764578])

# %%
lm.intercept_
# Out:
# -6119.219417591641

# %%
lm.coef_
# Out:
# array([-8.74422906e+01, -1.10276313e+02,  4.57590071e-01,  1.76113839e-01,
#        -1.07285376e+00,  2.93478054e+00, -3.48288633e+01, -1.47874149e-03])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# 0.8964386075383615
